# %% [markdown]
# <a href="https://colab.research.google.com/github/natasablagojevic/ip1/blob/main/Zadatak_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# Na skupu bank.csv izvr²iti sledece promene:

# %%
data = pd.read_csv("24-bank.csv")

# %%
data.head()
# Out:
#    STAROST             POSAO BRACNO_STANJE OBRAZOVANJE  \
# 0       30        nezaposlen       u_braku     osnevne
# 1       33            usluge       u_braku     srednje
# 2       35       rukovodstvo         samac      visoko
# 3       30       rukovodstvo       u_braku      visoko
# 4       59  manuelni_poslovi       u_braku     srednje
#
#    SREDNJE_GOD_STANJE_EUR STAMBENI_KREDIT LICNI_KREDIT    KONTAKT  \
# 0                    1787              ne           ne    mobilni
# 1                    4789              da           da    mobilni
# 2                    1350              da           ne    mobilni
# 3                    1476              da           da  nepoznato
# 4                       0              da           ne  nepoznato
#
#    DUZINA_RAZGOVORA_SEC  BROJ_RAZGOVORA OROCENA_STEDNJA
# 0                    79               1              ne
# 1                   220               1              ne
# 2                   185               1              ne
# ...

# %%
data.describe()
# Out:
#            STAROST  SREDNJE_GOD_STANJE_EUR  DUZINA_RAZGOVORA_SEC  \
# count  4521.000000             4521.000000           4521.000000
# mean     41.170095             1422.657819            263.961292
# std      10.576211             3009.638142            259.856633
# min      19.000000            -3313.000000              4.000000
# 25%      33.000000               69.000000            104.000000
# 50%      39.000000              444.000000            185.000000
# 75%      49.000000             1480.000000            329.000000
# max      87.000000            71188.000000           3025.000000
#
#        BROJ_RAZGOVORA
# count     4521.000000
# mean         2.793630
# std          3.109807
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         50.000000

# %%
# Eliminisati instance koje imaju negativnu vrednost u atributu srednje_god_stanje_eur.
data[data["SREDNJE_GOD_STANJE_EUR"] < 0] = pd.np.nan
data.dropna()
# Out:
# <ipython-input-20-a36ec45e4472>:2: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   data[data["SREDNJE_GOD_STANJE_EUR"] < 0] = pd.np.nan
#       STAROST             POSAO BRACNO_STANJE OBRAZOVANJE  \
# 0        30.0        nezaposlen       u_braku     osnevne
# 1        33.0            usluge       u_braku     srednje
# 2        35.0       rukovodstvo         samac      visoko
# 3        30.0       rukovodstvo       u_braku      visoko
# 4        59.0  manuelni_poslovi       u_braku     srednje
# ...       ...               ...           ...         ...
# 4514     38.0  manuelni_poslovi       u_braku     srednje
# 4515     32.0            usluge         samac     srednje
# 4518     57.0          tehnicar       u_braku     srednje
# 4519     28.0  manuelni_poslovi       u_braku     srednje
# 4520     44.0       preduzetnik         samac      visoko
#
# ...

# %%
data.describe()
# Out:
#            STAROST  SREDNJE_GOD_STANJE_EUR  DUZINA_RAZGOVORA_SEC  \
# count  4155.000000             4155.000000           4155.000000
# mean     41.297232             1577.000963            263.861372
# std      10.694177             3090.416228            260.473877
# min      19.000000                0.000000              4.000000
# 25%      33.000000              141.500000            104.000000
# 50%      39.000000              542.000000            186.000000
# 75%      49.000000             1637.000000            328.000000
# max      87.000000            71188.000000           3025.000000
#
#        BROJ_RAZGOVORA
# count     4155.000000
# mean         2.802888
# std          3.114009
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         50.000000

# %%
# Vrednosti atributa starost podeliti u 5 kategorija jednake širine.
import matplotlib.pyplot as plt
a, b, c = plt.hist(data["STAROST"], bins=5)
print(a, b, c)
# Out:
# [ 961. 1924. 1098.  134.   38.] [19.  32.6 46.2 59.8 73.4 87. ] <a list of 5 Patch objects>

# %%
# Promeniti kategorije atributa bracno_stanje u u_braku i nije_u_braku.
values = data["BRACNO_STANJE"].unique()
data["BRACNO_STANJE"].replace(values[1:], "nije_u_braku", inplace=True)

data["BRACNO_STANJE"].unique()
# Out:
# array(['u_braku', 'nije_u_braku'], dtype=object)

# %%
# Standardizovati numeri£ke atribute
